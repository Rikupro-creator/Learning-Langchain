# %% [markdown]
# <a href="https://colab.research.google.com/github/Rikupro-creator/Learning-Langchain/blob/main/Understanding_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my first attempt to understanding Langchain.  The material is based on this link - https://github.com/gkamradt/langchain-tutorials/blob/main/LangChain%20Cookbook%20Part%201%20-%20Fundamentals.ipynb

# %% [markdown]
# # what is langchain?
#
# Langchain is a framework for developing applications powered by language models.
#
# Langchain makes the complicate parts of working and building  with AI models easier. It helps to do this in two ways:
#
#
#   Integration - Bring external data, such as your files, other applications, and api data, to your LLMs
#
#   Agency -Allow your LLMs to interact with it's environment via decision making. Use LLMs to help decide which action to take next.

# %% [markdown]
# # Why langchain
#
# Components - Langchain makes it easy to swap out abstractions and components necessary to work with language models.
#
# Customized Chains -LangChain provides out of the box support for using and customizing 'chains' - a series of actions strung together.
#
# Speed - This team ships insanely fast. You'll  be up to date with the latest LLM features.
#
# Community - Wonderful discord and community support, meet ups, hackathons, etc.

# %%
pip install python-dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()

openai_api_key=os.getenv('OPENAI_API_KEY', '...')

# %% [markdown]
# # langchain components

# %% [markdown]
# ## we are focused on the schema and nuts that are necessary for langchain

# %% [markdown]
# ### Text
#
# This is the natural language way to interact with LLMs

# %%
my_text='when is today?'
my_text
# Out:
# 'when is today?'

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 10.0 MB/s eta 0:00:00
# ...

# %%
pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.0 MB/s eta 0:00:00
# ...

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.5 MB/s eta 0:00:00
# ...

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage


chat=ChatOpenAI(temperature=0.7, openai_api_key=openai_api_key)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %% [markdown]
# now lets create a message that simulates a chat experience

# %%
chat (
    [
        SystemMessage(content='You are a nice AI bot that helps a user figure out what to eat in one short sentence'),
        HumanMessage(content='I like tomatoes, what should I eat?')
    ]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# AIMessage(content='You could try a Caprese salad with fresh tomatoes, mozzarella, basil, and balsamic glaze.', response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 39, 'total_tokens': 62}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-65e51c77-e6dd-45f6-b2d3-09dd127c8428-0')

# %% [markdown]
# There is a chance to pass more chat history to the model

# %%
chat(
    [SystemMessage(content='You are a nice AI bot that helps a user figure out where to travel in one short sentence'),
    HumanMessage(content='I like the beaches where should I go?'),
    AIMessage(content='You should go to Nice, France'),
    HumanMessage(content='What else should I do when i\'m there?')
    ]
).content
# Out:
# 'Explore the charming Old Town, visit the vibrant flower market, and take a leisurely stroll along the Promenade des Anglais.'

# %%
content='What else should I do when i\'m there?'
content
# Out:
# "What else should I do when i'm there?"

# %% [markdown]
# you can also exclude system message in the chat

# %%
chat ([
    HumanMessage(content='What comes after, Thursday')
])
# Out:
# AIMessage(content='Friday', response_metadata={'token_usage': {'completion_tokens': 1, 'prompt_tokens': 12, 'total_tokens': 13}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1d3674b7-ee11-4f50-998d-f46337979c7d-0')

# %% [markdown]
# # Documents

# %%
from langchain.schema import Document

Document(
         page_content='This is my document. It is full of text that I\'ve gathered from other places',

         metadata={
             'my_document_id':234234,
             'my_document_source':'The langchain Papers',
             'my_document_create_time':1680013019
         }
         )
# Out:
# Document(page_content="This is my document. It is full of text that I've gathered from other places", metadata={'my_document_id': 234234, 'my_document_source': 'The langchain Papers', 'my_document_create_time': 1680013019})

# %%
system_instruction=SystemMessage(
    content="""You work as an assistant in an electronicts store.
    Your income depends on the items you sold"""

)

user_message=HumanMessage(content="3 bday gifts for a data scientist")
print(chat([system_instruction, user_message]).content)
# Out:
# 1. Smart Notebook - A reusable notebook that allows the data scientist to easily upload their notes to the cloud for safekeeping and organization.
#
# 2. Noise-Canceling Headphones - Essential for blocking out distractions while working on complex data analysis tasks.
#
# 3. External Hard Drive - Extra storage space for backing up important data and files, ensuring that the data scientist's work is always secure and accessible.

# %% [markdown]
# You can also omit the metadata

# %%
Document(
    page_content='This is my document.It is full of text that I\'ve gathered from  other places'
)
# Out:
# Document(page_content="This is my document.It is full of text that I've gathered from  other places")

# %% [markdown]
# # Models- The Interface to the AI brains

# %% [markdown]
# ## Language models

# %%
from langchain.llms import OpenAI
llm=OpenAI(openai_api_key=openai_api_key)
llm('Between Block Lesnar  and  Roman Reigns who is tougher?')
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ...

# %% [markdown]
# ## Chat model
#
# A model that takes a series of messages and returns a message output

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

chat=ChatOpenAI(temperature=1, openai_api_key=openai_api_key)

# %%
chat(
    [
        SystemMessage(content='You are an helpful AI bot that makes a joke at whatever the user says'),
        HumanMessage(content='I wouuld like to to to New York, how should I do this?')

    ]
)
# Out:
# AIMessage(content='Just make sure to bring a map - Google Maps, that is!', response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 43, 'total_tokens': 57}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c720484d-fb26-4eb2-9da0-ab0b3a91e596-0')

# %%
pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.1 MB/s eta 0:00:00
# ...

# %%
# Text Embeddin

from langchain.embeddings import OpenAIEmbeddings

text="""
Injuries to key players have marred the build-up for both teams coming into this fixture with Robert Lewandowski officially missing the opener for Poland and Frenkie de Jong ruled out of the tournament for the Dutch.

Poland come into this following a rough qualifying campaign which has now been compounded by the loss of Lewandowski. As we look to exploit what is likely to be a tough tournament for the Polish, one standout is their poor set-piece defending.

In Michał Probierz’s five competitive games in charge, 15 of the 34 shots they have allowed have come via set-plays, as have two of the three goals conceded. Who better to exploit this weakness than 6ft 5in Virgil Van Dijk. The Dutch captain has scored in both games leading up to the tournament and is also rumoured to be on penalties.
"""

Embeddings=OpenAIEmbeddings(openai_api_key=openai_api_key)
Embeddings.embed_query(text)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# [0.006679876830253275,
#  -0.007715359399781253,
#  0.035030437697801106,
#  -0.0029761661644620153,
#  -0.02030357800506608,
#  0.05869087648113654,
#  -0.011884360895441134,
#  0.00648022502923022,
#  0.0036140368793138268,
#  -0.01206032497365611,
#  0.009901377795492668,
#  0.019924578165426893,
#  -0.006405778831727349,
#  0.014253111755831098,
#  -0.0010320984927115074,
#  -0.01212123626087689,
#  0.020222362955438375,
#  -0.03178186551501374,
#  0.023186686189818874,
#  -0.03332494028206982,
#  -0.016716611644808328,
#  0.020438934558467202,
# ...

# %% [markdown]
# # Prompts - Text generally used as instructions to your model

# %%
from langchain.llms import OpenAI

llm=OpenAI(openai_api_key=openai_api_key)


prompt="""

Today is Monday, tomorrow is Wednesday.

What is wrong with that statement?
"""

print(llm(prompt))
# Out:
# The statement is incorrect because it skips a day (Tuesday) between Monday and Wednesday.

# %% [markdown]
# # Open source models

# %%
pip install auto-gptq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 53.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 44.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 45.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 83.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 38.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
from auto_gptq  import AutoGPTQForCausalLM
from transformers import AutoTokenizer
from torch import cuda

model_name="TheBloke/llama-2-13B-Guanaco-QLoRA-GPTQ"

# initalize the tokenizer for the model
tokenizer =AutoTokenizer.from_pretrained(model_name,use_fast=True)

# we initialize the AutoGPTQForCausalLm model with specific configurations
# This model is a quantizer version of the GPT model suitabel for efficient inference

model=AutoGPTQForCausalLM.from_quantized(
    model_name,
    use_safetensors=True,# Enables Safetensors for secure serialization
    trust_remote_code=True,# Trusts the remote code(not recommended for untrusted sources)
    device_map='auto', # Automatically maps the model to the available device
    quantize_config=None, #Custom quantication configuration (none for default)
    offload_folder="offload" # The folder to save the offloaded model
)

# the input query to be tokenized and passed to the model

query='I feel loved at the moment'

#Tokenize the input query and convert it to a tensor format compatible with CUDA
input_ids=tokenizer(query, return_tensors='pt').input_ids.cuda()
# genrate text using the model with the specifid temperature setting
output=model.generate(input_ids=input_ids,temperature=0.1)
output
# Out:
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# ...
